# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajwanti-Kumari/2026-ISYS5002-Labs/blob/main/01-labs/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
user_name = input("What is your name? ")
fav_colour = input("What is your favourite colour? ")
fav_food = input("What is your favourite food? ")
# Out:
# What is your name? Rajwanti
# What is your favourite colour? Black
# What is your favourite food? Pizza

# %%
print(user_name)
print(fav_colour)
print(fav_food)
# Out:
# Rajwanti
# Black
# Pizza

# %%
user_name = input("What is your name? ")
fav_colour = input("What is your favourite colour? ")
fav_food = input("What is your favourite food? ")
fav_drink = input("what is your favourite drink?")
location = input("where do you live? ")
# Out:
# What is your name? Rajwanti Kumari
# What is your favourite colour? Black
# What is your favourite food? Pizza
# what is your favourite drink?Water
# where do you live? Australia

# %%
print (user_name)
print (fav_colour)
print (fav_food)
print (fav_drink)
print (location)
# Out:
# Rajwanti Kumari
# Black
# Pizza
# Water
# Australia

# %%
print("Hello, " + user_name + "! Your favourite colour is " + fav_colour +
      " and you love " + fav_food + ", your favourite drink is " + fav_drink +  ", your current location is " + location + ".")
# Out:
# Hello, Rajwanti Kumari! Your favourite colour is Black and you love Pizza, your favourite drink is Water, your current location is Australia.
