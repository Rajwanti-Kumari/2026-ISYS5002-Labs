# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajwanti-Kumari/2026-ISYS5002-Labs/blob/main/01-labs/Week7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
{"name": "Widget A", "price": 9.99, "qty_sold": 120}
# Out:
# {'name': 'Widget A', 'price': 9.99, 'qty_sold': 120}

# %%
sales_data = {
    "P001": {"name": "Widget A", "price": 9.99, "qty_sold": 120},
    "P002": {"name": "Widget B", "price": 14.50, "qty_sold": 85},
    "P003": {"name": "Widget C", "price": 7.25, "qty_sold": 200},
    "P004": {"name": "Widget D", "price": 12.75, "qty_sold": 75}
}

# %%
total_revenue = 0

for product in sales_data.values():
    revenue = product["price"] * product["qty_sold"]
    total_revenue += revenue

print("Total Revenue:", total_revenue)
# Out:
# Total Revenue: 4837.55

# %%
best_product = None
highest_qty = 0

for product_id, product in sales_data.items():
    if product["qty_sold"] > highest_qty:
        highest_qty = product["qty_sold"]
        best_product = product["name"]

print("Best-selling product:", best_product)
print("Quantity sold:", highest_qty)
# Out:
# Best-selling product: Widget C
# Quantity sold: 200
