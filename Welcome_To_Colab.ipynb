# %% [markdown]
# <a href="https://colab.research.google.com/github/Rajwanti-Kumari/2026-ISYS5002-Labs/blob/main/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# #ISYS5002 - Week 1 Start
# In this notebook I will have my python Material

# %%
print ("hello world!")
# Out:
# hello world!

# %%
print ("Hey, Rajwanti!")
print ("Welcome to Australia")
# Out:
# Hey, Rajwanti!
# Welcome to Australia
